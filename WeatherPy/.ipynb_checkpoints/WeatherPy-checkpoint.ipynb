# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 593

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url)
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aketi
# Processing Record 2 of Set 1 | port-aux-francais
# Processing Record 3 of Set 1 | anchorage
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | vila franca do campo
# Processing Record 7 of Set 1 | enewetak
# Processing Record 8 of Set 1 | igarka
# Processing Record 9 of Set 1 | blackmans bay
# Processing Record 10 of Set 1 | weno
# Processing Record 11 of Set 1 | waterford
# Processing Record 12 of Set 1 | llallagua
# Processing Record 13 of Set 1 | ormond-by-the-sea
# Processing Record 14 of Set 1 | saudarkrokur
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | grytviken
# Processing Record 17 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | hawaiian paradise park
# Processing Record 20 of Set 1 | nova sintra
# Processing Record 21 of Set 1 | badger
# Processing Record 22 of Set 1 | waitangi
# Processing Record 23 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 24 of Set 1 | adamstown
# Processing Record 25 of Set 1 | fort bragg
# Processing Record 26 of Set 1 | anadyr
# Processing Record 27 of Set 1 | st. john's
# Processing Record 28 of Set 1 | kodiak
# Processing Record 29 of Set 1 | udachny
# Processing Record 30 of Set 1 | tralee
# Processing Record 31 of Set 1 | sodankyla
# Processing Record 32 of Set 1 | santa cruz
# Processing Record 33 of Set 1 | isafjordur
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | carnarvon
# Processing Record 36 of Set 1 | kasulu
# Processing Record 37 of Set 1 | phillipsburg
# Processing Record 38 of Set 1 | tazovsky
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | inhambane
# Processing Record 41 of Set 1 | plouzane
# Processing Record 42 of Set 1 | peniche
# Processing Record 43 of Set 1 | east london
# Processing Record 44 of Set 1 | colonia
# Processing Record 45 of Set 1 | antsiranana
# Processing Record 46 of Set 1 | cangzhou
# Processing Record 47 of Set 1 | edinburgh of the seven seas
# Processing Record 48 of Set 1 | nkhotakota
# Processing Record 49 of Set 1 | praia da vitoria
# Processing Record 50 of Set 1 | lodeve
# Processing Record 0 of Set 2 | qaqortoq
# Processing Record 1 of Set 2 | anloga
# Processing Record 2 of Set 2 | cabugao
# Processing Record 3 of Set 2 | mazatlan
# Processing Record 4 of Set 2 | puerto ayora
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | huamuxtitlan
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | sormiou
# City not found. Skipping...
# Processing Record 9 of Set 2 | borujen
# Processing Record 10 of Set 2 | kavieng
# Processing Record 11 of Set 2 | invercargill
# Processing Record 12 of Set 2 | karratha
# Processing Record 13 of Set 2 | holualoa
# Processing Record 14 of Set 2 | plastun
# Processing Record 15 of Set 2 | west island
# Processing Record 16 of Set 2 | attingal
# Processing Record 17 of Set 2 | ende
# Processing Record 18 of Set 2 | vernon
# Processing Record 19 of Set 2 | puerto natales
# Processing Record 20 of Set 2 | sheksna
# Processing Record 21 of Set 2 | qamdo
# Processing Record 22 of Set 2 | tazoult-lambese
# Processing Record 23 of Set 2 | fale old settlement
# Processing Record 24 of Set 2 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 25 of Set 2 | marsh harbour
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | huelma
# Processing Record 28 of Set 2 | gisborne
# Processing Record 29 of Set 2 | magadan
# Processing Record 30 of Set 2 | bereket
# Processing Record 31 of Set 2 | bilibino
# Processing Record 32 of Set 2 | college
# Processing Record 33 of Set 2 | pisco
# Processing Record 34 of Set 2 | fort st. john
# Processing Record 35 of Set 2 | crane
# Processing Record 36 of Set 2 | laela
# Processing Record 37 of Set 2 | abilene
# Processing Record 38 of Set 2 | noumea
# Processing Record 39 of Set 2 | mount pearl
# Processing Record 40 of Set 2 | lazaro cardenas
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | port elizabeth
# Processing Record 43 of Set 2 | bel ombre
# Processing Record 44 of Set 2 | junagarh
# Processing Record 45 of Set 2 | mangrol
# Processing Record 46 of Set 2 | daru
# Processing Record 47 of Set 2 | klyuchi
# Processing Record 48 of Set 2 | stanley
# Processing Record 49 of Set 2 | christchurch
# Processing Record 0 of Set 3 | wailua homesteads
# Processing Record 1 of Set 3 | katsuren-haebaru
# Processing Record 2 of Set 3 | dangriga
# Processing Record 3 of Set 3 | iqaluit
# Processing Record 4 of Set 3 | papatowai
# Processing Record 5 of Set 3 | hithadhoo
# Processing Record 6 of Set 3 | port glaud
# City not found. Skipping...
# Processing Record 7 of Set 3 | tutoia
# Processing Record 8 of Set 3 | keflavik
# Processing Record 9 of Set 3 | talnakh
# Processing Record 10 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 11 of Set 3 | dilling
# Processing Record 12 of Set 3 | bosaso
# Processing Record 13 of Set 3 | saint-philippe
# Processing Record 14 of Set 3 | poli
# Processing Record 15 of Set 3 | masterton
# Processing Record 16 of Set 3 | georgetown
# Processing Record 17 of Set 3 | whitehorse
# Processing Record 18 of Set 3 | remire-montjoly
# Processing Record 19 of Set 3 | avarua
# Processing Record 20 of Set 3 | bridlington
# Processing Record 21 of Set 3 | calama
# Processing Record 22 of Set 3 | kapa'a
# Processing Record 23 of Set 3 | novo aripuana
# Processing Record 24 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 25 of Set 3 | constantia
# Processing Record 26 of Set 3 | eyl
# Processing Record 27 of Set 3 | fortuna
# Processing Record 28 of Set 3 | segovia
# Processing Record 29 of Set 3 | masaya sur
# Processing Record 30 of Set 3 | buala
# Processing Record 31 of Set 3 | westhill
# Processing Record 32 of Set 3 | olonkinbyen
# Processing Record 33 of Set 3 | ponca city
# Processing Record 34 of Set 3 | dudinka
# Processing Record 35 of Set 3 | bouillon
# Processing Record 36 of Set 3 | nemuro
# Processing Record 37 of Set 3 | palmer
# Processing Record 38 of Set 3 | port augusta
# Processing Record 39 of Set 3 | fairfield
# Processing Record 40 of Set 3 | utrik
# Processing Record 41 of Set 3 | zvishavane
# Processing Record 42 of Set 3 | camacupa
# Processing Record 43 of Set 3 | ancud
# Processing Record 44 of Set 3 | vadso
# Processing Record 45 of Set 3 | kourou
# Processing Record 46 of Set 3 | ust-nera
# Processing Record 47 of Set 3 | canutama
# Processing Record 48 of Set 3 | disa
# Processing Record 49 of Set 3 | paphos
# Processing Record 0 of Set 4 | port mathurin
# Processing Record 1 of Set 4 | turpan
# Processing Record 2 of Set 4 | taounate
# Processing Record 3 of Set 4 | kailua-kona
# Processing Record 4 of Set 4 | lebu
# Processing Record 5 of Set 4 | tshikapa
# Processing Record 6 of Set 4 | langepas
# Processing Record 7 of Set 4 | bardai
# Processing Record 8 of Set 4 | yeniseysk
# Processing Record 9 of Set 4 | phu ly
# Processing Record 10 of Set 4 | margaret river
# Processing Record 11 of Set 4 | aykhal
# Processing Record 12 of Set 4 | vavuniya
# Processing Record 13 of Set 4 | karpinsk
# Processing Record 14 of Set 4 | acapulco de juarez
# Processing Record 15 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 16 of Set 4 | urangan
# Processing Record 17 of Set 4 | ii
# City not found. Skipping...
# Processing Record 18 of Set 4 | at taj
# Processing Record 19 of Set 4 | esmeralda
# Processing Record 20 of Set 4 | huarmey
# Processing Record 21 of Set 4 | salinas
# Processing Record 22 of Set 4 | cill airne
# Processing Record 23 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 24 of Set 4 | cholpon-ata
# Processing Record 25 of Set 4 | kargasok
# Processing Record 26 of Set 4 | ilulissat
# Processing Record 27 of Set 4 | xining
# Processing Record 28 of Set 4 | harper
# Processing Record 29 of Set 4 | labrador city
# Processing Record 30 of Set 4 | quang ngai
# Processing Record 31 of Set 4 | tidjikja
# Processing Record 32 of Set 4 | boguchany
# Processing Record 33 of Set 4 | malaryta
# Processing Record 34 of Set 4 | saint-pierre
# Processing Record 35 of Set 4 | balkh
# Processing Record 36 of Set 4 | vilyuchinsk
# Processing Record 37 of Set 4 | luganville
# Processing Record 38 of Set 4 | hasaki
# Processing Record 39 of Set 4 | al muwayh
# Processing Record 40 of Set 4 | kone
# Processing Record 41 of Set 4 | alice springs
# Processing Record 42 of Set 4 | kingston
# Processing Record 43 of Set 4 | hilton head island
# Processing Record 44 of Set 4 | dunedin
# Processing Record 45 of Set 4 | thompson
# Processing Record 46 of Set 4 | lata
# Processing Record 47 of Set 4 | sitka
# Processing Record 48 of Set 4 | susuman
# Processing Record 49 of Set 4 | lautoka
# Processing Record 0 of Set 5 | kavaratti
# Processing Record 1 of Set 5 | maceio
# Processing Record 2 of Set 5 | suva
# Processing Record 3 of Set 5 | bakaly
# Processing Record 4 of Set 5 | sinop
# Processing Record 5 of Set 5 | den burg
# Processing Record 6 of Set 5 | toboso
# Processing Record 7 of Set 5 | motueka
# Processing Record 8 of Set 5 | la gomera
# Processing Record 9 of Set 5 | arno
# Processing Record 10 of Set 5 | sandnessjoen
# Processing Record 11 of Set 5 | port alfred
# Processing Record 12 of Set 5 | severo-yeniseyskiy
# Processing Record 13 of Set 5 | guymon
# Processing Record 14 of Set 5 | qom
# Processing Record 15 of Set 5 | ta`u
# Processing Record 16 of Set 5 | toropets
# Processing Record 17 of Set 5 | binh long
# City not found. Skipping...
# Processing Record 18 of Set 5 | camarinas
# Processing Record 19 of Set 5 | tabas
# Processing Record 20 of Set 5 | lembar
# City not found. Skipping...
# Processing Record 21 of Set 5 | howrah
# Processing Record 22 of Set 5 | gaspra
# Processing Record 23 of Set 5 | kirensk
# Processing Record 24 of Set 5 | kostopil'
# Processing Record 25 of Set 5 | naracoorte
# Processing Record 26 of Set 5 | saipan
# Processing Record 27 of Set 5 | yishui
# Processing Record 28 of Set 5 | havre
# Processing Record 29 of Set 5 | sonsorol village
# City not found. Skipping...
# Processing Record 30 of Set 5 | nyagan
# Processing Record 31 of Set 5 | bihpuriagaon
# Processing Record 32 of Set 5 | big rapids
# Processing Record 33 of Set 5 | yanam
# Processing Record 34 of Set 5 | nuuk
# Processing Record 35 of Set 5 | cassilandia
# Processing Record 36 of Set 5 | demre
# Processing Record 37 of Set 5 | arraial do cabo
# Processing Record 38 of Set 5 | san rafael del sur
# Processing Record 39 of Set 5 | gaogou
# Processing Record 40 of Set 5 | bamboo flat
# Processing Record 41 of Set 5 | inverloch
# Processing Record 42 of Set 5 | kapuskasing
# Processing Record 43 of Set 5 | aracuai
# Processing Record 44 of Set 5 | tiksi
# Processing Record 45 of Set 5 | shakhtinsk
# Processing Record 46 of Set 5 | port hedland
# Processing Record 47 of Set 5 | sao lourenco do oeste
# Processing Record 48 of Set 5 | outapi
# City not found. Skipping...
# Processing Record 49 of Set 5 | gonabad
# Processing Record 0 of Set 6 | bull savanna
# Processing Record 1 of Set 6 | cururupu
# Processing Record 2 of Set 6 | papao
# Processing Record 3 of Set 6 | terenozek
# Processing Record 4 of Set 6 | black forest
# Processing Record 5 of Set 6 | sao vicente
# Processing Record 6 of Set 6 | horta
# Processing Record 7 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 8 of Set 6 | gazojak
# Processing Record 9 of Set 6 | la passe
# Processing Record 10 of Set 6 | gondar
# Processing Record 11 of Set 6 | thakhek
# Processing Record 12 of Set 6 | qacha's nek
# Processing Record 13 of Set 6 | lethem
# Processing Record 14 of Set 6 | hirara
# Processing Record 15 of Set 6 | kalmunai
# Processing Record 16 of Set 6 | bathsheba
# Processing Record 17 of Set 6 | mukalla
# Processing Record 18 of Set 6 | cavelossim
# Processing Record 19 of Set 6 | yeraliyev
# Processing Record 20 of Set 6 | dakhla
# Processing Record 21 of Set 6 | lucapa
# Processing Record 22 of Set 6 | dunda
# Processing Record 23 of Set 6 | arteche
# Processing Record 24 of Set 6 | tokmok
# Processing Record 25 of Set 6 | namibe
# Processing Record 26 of Set 6 | aripuana
# Processing Record 27 of Set 6 | cestos city
# Processing Record 28 of Set 6 | bogale
# Processing Record 29 of Set 6 | dholka
# Processing Record 30 of Set 6 | kumylzhenskaya
# Processing Record 31 of Set 6 | we
# City not found. Skipping...
# Processing Record 32 of Set 6 | parauapebas
# Processing Record 33 of Set 6 | ad darb
# Processing Record 34 of Set 6 | hamilton
# Processing Record 35 of Set 6 | chonchi
# Processing Record 36 of Set 6 | altai
# Processing Record 37 of Set 6 | fortuna foothills
# Processing Record 38 of Set 6 | vershino-darasunskiy
# Processing Record 39 of Set 6 | ouellah
# City not found. Skipping...
# Processing Record 40 of Set 6 | tolanaro
# Processing Record 41 of Set 6 | iskateley
# Processing Record 42 of Set 6 | vorgashor
# Processing Record 43 of Set 6 | port lincoln
# Processing Record 44 of Set 6 | amahai
# Processing Record 45 of Set 6 | katsuura
# Processing Record 46 of Set 6 | mbaiki
# Processing Record 47 of Set 6 | polovinnoye
# Processing Record 48 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 49 of Set 6 | amga
# Processing Record 0 of Set 7 | salekhard
# Processing Record 1 of Set 7 | klaksvik
# Processing Record 2 of Set 7 | ola
# Processing Record 3 of Set 7 | bangassou
# Processing Record 4 of Set 7 | manuguru
# Processing Record 5 of Set 7 | kampung sungai ara
# Processing Record 6 of Set 7 | solleftea
# Processing Record 7 of Set 7 | loikaw
# Processing Record 8 of Set 7 | estacion coahuila
# Processing Record 9 of Set 7 | kathmandu
# Processing Record 10 of Set 7 | hami
# Processing Record 11 of Set 7 | belyy yar
# Processing Record 12 of Set 7 | atafu village
# Processing Record 13 of Set 7 | tofol
# Processing Record 14 of Set 7 | greeley
# Processing Record 15 of Set 7 | vilyuysk
# Processing Record 16 of Set 7 | rio gallegos
# Processing Record 17 of Set 7 | adrar
# Processing Record 18 of Set 7 | kyzyl-suu
# Processing Record 19 of Set 7 | talcahuano
# Processing Record 20 of Set 7 | chauk
# Processing Record 21 of Set 7 | rukban
# City not found. Skipping...
# Processing Record 22 of Set 7 | cidreira
# Processing Record 23 of Set 7 | cova figueira
# Processing Record 24 of Set 7 | saldanha
# Processing Record 25 of Set 7 | matamba
# Processing Record 26 of Set 7 | punahana
# Processing Record 27 of Set 7 | qarah bagh
# Processing Record 28 of Set 7 | punta cana
# Processing Record 29 of Set 7 | luderitz
# Processing Record 30 of Set 7 | polyarnyy
# Processing Record 31 of Set 7 | mpika
# Processing Record 32 of Set 7 | pallasovka
# Processing Record 33 of Set 7 | torrington
# Processing Record 34 of Set 7 | senador pompeu
# Processing Record 35 of Set 7 | kulhudhuffushi
# Processing Record 36 of Set 7 | kununurra
# Processing Record 37 of Set 7 | port douglas
# Processing Record 38 of Set 7 | darwin
# Processing Record 39 of Set 7 | nova vicosa
# Processing Record 40 of Set 7 | andergrove
# Processing Record 41 of Set 7 | rocky mount
# Processing Record 42 of Set 7 | guixi
# Processing Record 43 of Set 7 | flying fish cove
# Processing Record 44 of Set 7 | belmonte
# Processing Record 45 of Set 7 | nayoro
# Processing Record 46 of Set 7 | madara
# Processing Record 47 of Set 7 | mont-laurier
# Processing Record 48 of Set 7 | meadow lakes
# Processing Record 49 of Set 7 | aksu
# Processing Record 0 of Set 8 | mae hong son
# Processing Record 1 of Set 8 | walvis bay
# Processing Record 2 of Set 8 | parsberg
# Processing Record 3 of Set 8 | mount isa
# Processing Record 4 of Set 8 | bubaque
# Processing Record 5 of Set 8 | los angeles
# Processing Record 6 of Set 8 | labuan bajo
# Processing Record 7 of Set 8 | penzance
# Processing Record 8 of Set 8 | nouadhibou
# Processing Record 9 of Set 8 | sovetskiy
# Processing Record 10 of Set 8 | arkhangel'sk
# Processing Record 11 of Set 8 | san jeronimo de juarez
# Processing Record 12 of Set 8 | kikwit
# Processing Record 13 of Set 8 | guerrero negro
# Processing Record 14 of Set 8 | tura
# Processing Record 15 of Set 8 | talara
# Processing Record 16 of Set 8 | lerwick
# Processing Record 17 of Set 8 | suntar
# Processing Record 18 of Set 8 | nar'yan-mar
# Processing Record 19 of Set 8 | uvinza
# Processing Record 20 of Set 8 | aasiaat
# Processing Record 21 of Set 8 | governor's harbour
# City not found. Skipping...
# Processing Record 22 of Set 8 | thunder bay
# Processing Record 23 of Set 8 | uturoa
# Processing Record 24 of Set 8 | villa emilio carranza
# Processing Record 25 of Set 8 | vila velha
# Processing Record 26 of Set 8 | safotu
# Processing Record 27 of Set 8 | san luis de la loma
# Processing Record 28 of Set 8 | new norfolk
# Processing Record 29 of Set 8 | sorong
# Processing Record 30 of Set 8 | oberstdorf
# Processing Record 31 of Set 8 | dalandzadgad
# Processing Record 32 of Set 8 | kloulklubed
# Processing Record 33 of Set 8 | sao joao da barra
# Processing Record 34 of Set 8 | mejit
# Processing Record 35 of Set 8 | vallenar
# Processing Record 36 of Set 8 | timmins
# Processing Record 37 of Set 8 | san antonio de pale
# Processing Record 38 of Set 8 | jaigaon
# Processing Record 39 of Set 8 | hotan
# Processing Record 40 of Set 8 | santa maria do suacui
# Processing Record 41 of Set 8 | kolonia
# Processing Record 42 of Set 8 | tanumah
# Processing Record 43 of Set 8 | 'ain el hadjel
# City not found. Skipping...
# Processing Record 44 of Set 8 | port saint john's
# Processing Record 45 of Set 8 | grenville
# Processing Record 46 of Set 8 | nizhneudinsk
# Processing Record 47 of Set 8 | moultonborough
# Processing Record 48 of Set 8 | pijao
# Processing Record 49 of Set 8 | tibanbang
# Processing Record 0 of Set 9 | nyazepetrovsk
# Processing Record 1 of Set 9 | rongelap
# Processing Record 2 of Set 9 | yeppoon
# Processing Record 3 of Set 9 | carnot
# Processing Record 4 of Set 9 | punta del este
# Processing Record 5 of Set 9 | ried im innkreis
# Processing Record 6 of Set 9 | reggane
# Processing Record 7 of Set 9 | franca
# Processing Record 8 of Set 9 | laguna
# Processing Record 9 of Set 9 | yaren
# Processing Record 10 of Set 9 | quepos
# Processing Record 11 of Set 9 | ishigaki
# Processing Record 12 of Set 9 | alaghsas
# Processing Record 13 of Set 9 | mata-utu
# Processing Record 14 of Set 9 | ahau
# City not found. Skipping...
# Processing Record 15 of Set 9 | tete
# Processing Record 16 of Set 9 | khandyga
# Processing Record 17 of Set 9 | fauske
# Processing Record 18 of Set 9 | simplicio mendes
# Processing Record 19 of Set 9 | pingliang
# Processing Record 20 of Set 9 | trairi
# Processing Record 21 of Set 9 | coquimbo
# Processing Record 22 of Set 9 | mar del plata
# Processing Record 23 of Set 9 | mandal
# Processing Record 24 of Set 9 | callaway
# Processing Record 25 of Set 9 | inarajan village
# Processing Record 26 of Set 9 | nossa senhora da gloria
# Processing Record 27 of Set 9 | novotroitsk
# Processing Record 28 of Set 9 | tambopata
# Processing Record 29 of Set 9 | champoton
# Processing Record 30 of Set 9 | yuzhno-kurilsk
# Processing Record 31 of Set 9 | takoradi
# Processing Record 32 of Set 9 | sakaraha
# Processing Record 33 of Set 9 | gamba
# Processing Record 34 of Set 9 | caconda
# Processing Record 35 of Set 9 | pasargad
# City not found. Skipping...
# Processing Record 36 of Set 9 | tanrake village
# City not found. Skipping...
# Processing Record 37 of Set 9 | apostolove
# Processing Record 38 of Set 9 | troitskoye
# Processing Record 39 of Set 9 | corn island
# Processing Record 40 of Set 9 | morris
# Processing Record 41 of Set 9 | novopskov
# Processing Record 42 of Set 9 | egilsstadir
# Processing Record 43 of Set 9 | ortakoy
# Processing Record 44 of Set 9 | copiapo
# Processing Record 45 of Set 9 | manado
# Processing Record 46 of Set 9 | sechura
# Processing Record 47 of Set 9 | codrington
# Processing Record 48 of Set 9 | cartagena
# Processing Record 49 of Set 9 | priob'ye
# Processing Record 0 of Set 10 | graaff-reinet
# Processing Record 1 of Set 10 | santa marta
# Processing Record 2 of Set 10 | jacksonville
# Processing Record 3 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 10 | thief river falls
# Processing Record 5 of Set 10 | benemerito de las americas
# Processing Record 6 of Set 10 | ryotsu-minato
# Processing Record 7 of Set 10 | pointe-noire
# Processing Record 8 of Set 10 | sisimiut
# Processing Record 9 of Set 10 | el charco
# Processing Record 10 of Set 10 | archangelos
# Processing Record 11 of Set 10 | ridgecrest
# Processing Record 12 of Set 10 | necochea
# Processing Record 13 of Set 10 | gao
# Processing Record 14 of Set 10 | barabai
# Processing Record 15 of Set 10 | mezhdurechensk
# Processing Record 16 of Set 10 | floro
# Processing Record 17 of Set 10 | lagunas
# Processing Record 18 of Set 10 | tananger
# Processing Record 19 of Set 10 | laojunmiao
# Processing Record 20 of Set 10 | oleksandriys'ke
# Processing Record 21 of Set 10 | imbituba
# Processing Record 22 of Set 10 | kayangel
# Processing Record 23 of Set 10 | zakynthos
# Processing Record 24 of Set 10 | ca mau
# Processing Record 25 of Set 10 | zaozersk
# Processing Record 26 of Set 10 | portland
# Processing Record 27 of Set 10 | burang
# Processing Record 28 of Set 10 | ratnagiri
# Processing Record 29 of Set 10 | ankazoabo
# Processing Record 30 of Set 10 | naivasha
# Processing Record 31 of Set 10 | geraldton
# Processing Record 32 of Set 10 | al buraymi
# Processing Record 33 of Set 10 | sumbe
# Processing Record 34 of Set 10 | gadzhiyevo
# Processing Record 35 of Set 10 | togur
# Processing Record 36 of Set 10 | brokopondo
# Processing Record 37 of Set 10 | luanco
# Processing Record 38 of Set 10 | poyarkovo
# Processing Record 39 of Set 10 | taksimo
# Processing Record 40 of Set 10 | kirakira
# Processing Record 41 of Set 10 | kyaikkami
# Processing Record 42 of Set 10 | koksan
# Processing Record 43 of Set 10 | kota kinabalu
# Processing Record 44 of Set 10 | cabo san lucas
# Processing Record 45 of Set 10 | ligny-en-barrois
# Processing Record 46 of Set 10 | wa
# City not found. Skipping...
# Processing Record 47 of Set 10 | klina
# Processing Record 48 of Set 10 | mogok
# Processing Record 49 of Set 10 | espargos
# City not found. Skipping...
# Processing Record 0 of Set 11 | palikir - national government center
# Processing Record 1 of Set 11 | changuinola
# Processing Record 2 of Set 11 | zabol
# Processing Record 3 of Set 11 | cabeza del buey
# Processing Record 4 of Set 11 | luorong
# Processing Record 5 of Set 11 | veraval
# Processing Record 6 of Set 11 | hadibu
# Processing Record 7 of Set 11 | afaahiti
# Processing Record 8 of Set 11 | gejiu
# Processing Record 9 of Set 11 | saint croix
# Processing Record 10 of Set 11 | rabaul
# Processing Record 11 of Set 11 | grand falls-windsor
# Processing Record 12 of Set 11 | erenhot
# Processing Record 13 of Set 11 | turochak
# Processing Record 14 of Set 11 | la gi
# Processing Record 15 of Set 11 | ponta delgada
# Processing Record 16 of Set 11 | kodinsk
# Processing Record 17 of Set 11 | santa vitoria do palmar
# Processing Record 18 of Set 11 | alo
# Processing Record 19 of Set 11 | maubara
# City not found. Skipping...
# Processing Record 20 of Set 11 | kem'
# Processing Record 21 of Set 11 | nadi
# Processing Record 22 of Set 11 | mount gambier
# Processing Record 23 of Set 11 | lubang
# Processing Record 24 of Set 11 | stara zagora
# Processing Record 25 of Set 11 | hammerfest
# Processing Record 26 of Set 11 | esfarayen
# Processing Record 27 of Set 11 | neka
# Processing Record 28 of Set 11 | hastings
# Processing Record 29 of Set 11 | isangel
# Processing Record 30 of Set 11 | san juan
# Processing Record 31 of Set 11 | bodo
# Processing Record 32 of Set 11 | mbandaka
# Processing Record 33 of Set 11 | zyryanskoye
# Processing Record 34 of Set 11 | plettenberg bay
# Processing Record 35 of Set 11 | kidal
# Processing Record 36 of Set 11 | severnoye
# Processing Record 37 of Set 11 | kostomuksha
# Processing Record 38 of Set 11 | nieuw amsterdam
# Processing Record 39 of Set 11 | tangalle
# Processing Record 40 of Set 11 | santa ana
# Processing Record 41 of Set 11 | san patricio
# Processing Record 42 of Set 11 | ambon
# Processing Record 43 of Set 11 | naze
# Processing Record 44 of Set 11 | perry
# Processing Record 45 of Set 11 | okoneshnikovo
# Processing Record 46 of Set 11 | puerto deseado
# Processing Record 47 of Set 11 | chayan
# Processing Record 48 of Set 11 | fenoarivo atsinanana
# Processing Record 49 of Set 11 | smithers
# Processing Record 0 of Set 12 | miracema do tocantins
# Processing Record 1 of Set 12 | arfoud
# Processing Record 2 of Set 12 | conde
# Processing Record 3 of Set 12 | mahdia
# Processing Record 4 of Set 12 | yangor
# City not found. Skipping...
# Processing Record 5 of Set 12 | ringkobing
# Processing Record 6 of Set 12 | labytnangi
# Processing Record 7 of Set 12 | murun-kuren
# Processing Record 8 of Set 12 | urengoy
# Processing Record 9 of Set 12 | i-n-salah
# Processing Record 10 of Set 12 | nizhnesortymskiy
# Processing Record 11 of Set 12 | arica
# Processing Record 12 of Set 12 | tiznit
# Processing Record 13 of Set 12 | haiku-pauwela
# Processing Record 14 of Set 12 | palamas
# Processing Record 15 of Set 12 | seogwipo
# City not found. Skipping...
# Processing Record 16 of Set 12 | bongaree
# Processing Record 17 of Set 12 | hilo
# Processing Record 18 of Set 12 | axim
# Processing Record 19 of Set 12 | cabedelo
# Processing Record 20 of Set 12 | berezovyy
# Processing Record 21 of Set 12 | campbell river
# Processing Record 22 of Set 12 | nadym
# Processing Record 23 of Set 12 | greenville
# Processing Record 24 of Set 12 | taltal
# Processing Record 25 of Set 12 | gordonvale
# Processing Record 26 of Set 12 | margate
# Processing Record 27 of Set 12 | duluth
# Processing Record 28 of Set 12 | touros
# Processing Record 29 of Set 12 | berdigestyakh
# Processing Record 30 of Set 12 | bahia de caraquez
# Processing Record 31 of Set 12 | guatrache
# Processing Record 32 of Set 12 | kaitong
# Processing Record 33 of Set 12 | woolgoolga
# Processing Record 34 of Set 12 | kili
# Processing Record 35 of Set 12 | akureyri
# Processing Record 36 of Set 12 | tanjung selor
# City not found. Skipping...
# Processing Record 37 of Set 12 | tayshet
# Processing Record 38 of Set 12 | puerto real
# Processing Record 39 of Set 12 | progreso
# Processing Record 40 of Set 12 | mayahi
# Processing Record 41 of Set 12 | raja
# Processing Record 42 of Set 12 | najran
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              aketi   2.7388   23.7833    295.47        97         100
# 1  port-aux-francais -49.3500   70.2167    278.90        96         100
# 2          anchorage  61.2181 -149.9003    291.90        79          75
# 3       punta arenas -53.1500  -70.9167    274.21        93         100
# 4            ushuaia -54.8000  -68.3000    272.96       100          75
#
#    Wind Speed Country        Date
# 0        1.11      CD  1719791554
# 1       11.27      TF  1719791555
# 2        3.13      US  1719791556
# 3        2.06      CL  1719791558
# 4        0.51      AR  1719791559

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                    aketi   2.7388   23.7833    295.47        97         100
# 1        port-aux-francais -49.3500   70.2167    278.90        96         100
# 2                anchorage  61.2181 -149.9003    291.90        79          75
# 3             punta arenas -53.1500  -70.9167    274.21        93         100
# 4                  ushuaia -54.8000  -68.3000    272.96       100          75
#
#          Wind Speed Country        Date
# City_ID
# 0              1.11      CD  1719791554
# 1             11.27      TF  1719791555
# 2              3.13      US  1719791556
# 3              2.06      CL  1719791558
# 4              0.51      AR  1719791559

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title(f"City Max Latitude vs Temperature (2024-06-17)")

# Incorporate the other graph properties
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f"City Latitude vs Humidity")



# Incorporate the other graph properties
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f"City Latitude vs Cloudiness (2024-06-17)")

# Incorporate the other graph properties
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title(f"City Latitude vs Wind Speed (2024-06-17)")

# Incorporate the other graph properties
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]
# Display sample data
northern_hemi_df.head()
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                       aketi   2.7388   23.7833    295.47        97
# 2                   anchorage  61.2181 -149.9003    291.90        79
# 5        vila franca do campo  37.7167  -25.4333    293.38        99
# 6                    enewetak  11.3474  162.3373    301.65        78
# 7                      igarka  67.4667   86.5833    282.58        58
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        1.11      CD  1719791554
# 2                75        3.13      US  1719791556
# 5                70        4.05      PT  1719791561
# 6                49        7.47      MH  1719791562
# 7                62        3.41      RU  1719791563

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        port-aux-francais -49.3500   70.2167    278.90        96         100
# 3             punta arenas -53.1500  -70.9167    274.21        93         100
# 4                  ushuaia -54.8000  -68.3000    272.96       100          75
# 8            blackmans bay -43.0167  147.3167    279.67        81          65
# 11               llallagua -18.4167  -66.6333    278.08        26           0
#
#          Wind Speed Country        Date
# City_ID
# 1             11.27      TF  1719791555
# 3              2.06      CL  1719791558
# 4              0.51      AR  1719791559
# 8              1.80      AU  1719791565
# 11             1.93      BO  1719791569

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Build scatter plot for latitude vs. temperature
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title(f"City Max Latitude vs Max Temp")
plt.plot(x_values, regress_values, "r-", label='Regression line')
# Incorporate the other graph properties
plt.grid(True)
plt.annotate(line_eq, (x_values.min(), y_values.min()), fontsize=15, color="red")
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
print(f"The r^2-value is: {rvalue**2}")
# Out:
# The r^2-value is: 0.47777299907807164

# %%
# Linear regression on Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Build scatter plot for latitude vs. temperature
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title(f"City Max Latitude vs Max Temp")
plt.plot(x_values, regress_values, "r-", label='Regression line')
# Incorporate the other graph properties
plt.grid(True)
plt.annotate(line_eq, (x_values.min(), y_values.min()), fontsize=15, color="red")
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
print(f"The r^2-value is: {rvalue**2}")
# Out:
# The r^2-value is: 0.5695995405930736

# %% [markdown]
# **Discussion about the linear relationship: There is definately a strong linear correllation between these 2 graphs.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Build scatter plot for latitude vs. temperature
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f"Latitude vs Humidity")
plt.plot(x_values, regress_values, "r-")
# Incorporate the other graph properties
plt.grid(True)
plt.annotate(line_eq, (x_values.min(), y_values.min()), fontsize=15, color="red")
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
print(f"The r^2-value is: {rvalue**2}")
# Out:
# The r^2-value is: 0.002433028612060519

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# Build scatter plot for latitude vs. temperature
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f"Latitude vs Humidity")
plt.plot(x_values, regress_values, "r-")
# Incorporate the other graph properties
plt.grid(True)
plt.annotate(line_eq, (x_values.min(), y_values.min()), fontsize=15, color="red")
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
print(f"The r^2-value is: {rvalue**2}")
# Out:
# The r^2-value is: 0.002450670837059501

# %% [markdown]
# **Discussion about the linear relationship: The linear relationships between these graphs shows a very weak linear regression, although there is still a correlation.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Build scatter plot for latitude vs. temperature
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f"Latitude vs Cloundiness")
plt.plot(x_values, regress_values, "r-")
# Incorporate the other graph properties
plt.grid(True)
plt.annotate(line_eq, (x_values.min(), y_values.min()), fontsize=15, color="red")
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
print(f"The r^2-value is: {rvalue**2}")
# Out:
# The r^2-value is: 6.350132564119539e-05

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Build scatter plot for latitude vs. temperature
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f"Latitude vs Cloundiness")
plt.plot(x_values, regress_values, "r-")
# Incorporate the other graph properties
plt.grid(True)
plt.annotate(line_eq, (x_values.min(), y_values.min()), fontsize=15, color="red")
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
print(f"The r^2-value is: {rvalue**2}")
# Out:
# The r^2-value is: 0.002450670837059501

# %% [markdown]
# **Discussion about the linear relationship: In regrads to latitude to cloundiness, there is no clear relation at all.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Build scatter plot for latitude vs. temperature
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f"Latitude vs Wind Speed")
plt.plot(x_values, regress_values, "r-")
# Incorporate the other graph properties
plt.grid(True)
plt.annotate(line_eq, (x_values.min(), y_values.min()), fontsize=15, color="red")
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
print(f"The r^2-value is: {rvalue**2}")
# Out:
# The r^2-value is: 0.005877620496585746

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Build scatter plot for latitude vs. temperature
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f"Latitude vs Wind Speed")
plt.plot(x_values, regress_values, "r-")
# Incorporate the other graph properties
plt.grid(True)
plt.annotate(line_eq, (x_values.min(), y_values.min()), fontsize=15, color="red")
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
print(f"The r^2-value is: {rvalue**2}")
# Out:
# The r^2-value is: 0.0005175888882511426

# %% [markdown]
# **Discussion about the linear relationship:As for Latitude and wind speed there is a slight correlation, but not strong at all.
